# %% [markdown]
# <a href="https://colab.research.google.com/github/onemorenight-me2013/ACM-Recruitment-Phase-2--Ragini-Gupta/blob/main/AI%20-The%20Data%20Trials/The%20Missing%20values/Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("train.csv")
df["Age"]=df["Age"].fillna(df["Age"].median())# using the median value of age to fill the null values in age column
print(df["Age"])
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64
